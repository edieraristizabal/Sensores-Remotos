# %% [markdown]
# # Tutorial para clasificación de imagenes de satélite

# %% [markdown]
# En este artículo exploraremos cómo clasificar el uso del suelo en imágenes satelitales. Utilizaremos índices espectrales para diferenciar entre:
# * **Suelo desnudo**
# * **Bosques**
# * **Campos agrícolas**
# * **Cuerpos de agua**

# %%
import rioxarray
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
